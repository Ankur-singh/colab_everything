# %% [raw]
# ---
# description: Fill in a module description here
# output-file: core.html
# title: core
#
# ---

# %% [markdown]
# <!-- WARNING: THIS FILE WAS AUTOGENERATED! DO NOT EDIT! -->

# %%
#|output: asis
#| echo: false
show_doc(ColabBase)
# Out:
# ---
#
# [source](https://github.com/Ankur-singh/colab_everything/blob/master/colab_everything/core.py#L12){target="_blank" style="float:right; font-size:smaller"}
#
# ### ColabBase
#
# >      ColabBase (port=9999)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(ColabStreamlit)
# Out:
# ---
#
# [source](https://github.com/Ankur-singh/colab_everything/blob/master/colab_everything/core.py#L26){target="_blank" style="float:right; font-size:smaller"}
#
# ### ColabStreamlit
#
# >      ColabStreamlit (path, port=9999)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(ColabFlask)
# Out:
# ---
#
# [source](https://github.com/Ankur-singh/colab_everything/blob/master/colab_everything/core.py#L46){target="_blank" style="float:right; font-size:smaller"}
#
# ### ColabFlask
#
# >      ColabFlask (path, port=9999)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(ColabFastapi)
# Out:
# ---
#
# [source](https://github.com/Ankur-singh/colab_everything/blob/master/colab_everything/core.py#L66){target="_blank" style="float:right; font-size:smaller"}
#
# ### ColabFastapi
#
# >      ColabFastapi (path, app='app', port=9999)
#
# Initialize self.  See help(type(self)) for accurate signature.

# %%
#|output: asis
#| echo: false
show_doc(ColabCustom)
# Out:
# ---
#
# [source](https://github.com/Ankur-singh/colab_everything/blob/master/colab_everything/core.py#L87){target="_blank" style="float:right; font-size:smaller"}
#
# ### ColabCustom
#
# >      ColabCustom (cmd, port=9999)
#
# Initialize self.  See help(type(self)) for accurate signature.
